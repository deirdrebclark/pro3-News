# %%
import pprint 
import requests 
import eventregistry
import feedparser as fp
import json
from newsapi import NewsApiClient
from datetime import date
import datetime
import pandas as pd
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize.regexp import WhitespaceTokenizer
import numpy as np
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /Users/hsaul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/hsaul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
newsapi = NewsApiClient(api_key='f513e29c94b844758f79311e9e081927')

all_articles = newsapi.get_everything(q='coronavirus',
                                      sources= 'abc-news',
                                      from_param=str(date.today() -datetime.timedelta(days=29)),
                                      to= str(date.today()),
                                      language='en',
                                      sort_by='relevancy',
                                      page_size=100,
                                      page=1)

# %%
def get_sources(country):
    sources = newsapi.get_sources(country=country)
    sources = [x['id'] for x in sources['sources']]
    return sources

sources= get_sources(country='us')
print(sources[:200])

# %%
data_abc= pd.DataFrame(all_articles['articles'])
data_abc
# Out:
#                                     source  \
# 0   {'id': 'abc-news', 'name': 'ABC News'}
# 1   {'id': 'abc-news', 'name': 'ABC News'}
# 2   {'id': 'abc-news', 'name': 'ABC News'}
# 3   {'id': 'abc-news', 'name': 'ABC News'}
# 4   {'id': 'abc-news', 'name': 'ABC News'}
# ..                                     ...
# 95  {'id': 'abc-news', 'name': 'ABC News'}
# 96  {'id': 'abc-news', 'name': 'ABC News'}
# 97  {'id': 'abc-news', 'name': 'ABC News'}
# 98  {'id': 'abc-news', 'name': 'ABC News'}
# 99  {'id': 'abc-news', 'name': 'ABC News'}
#
#                                      author  \
# 0                              Libby Cathey
# 1                               Jon Haworth
# 2                              Libby Cathey
# 3                            Erin Schumaker
# 4                ALAN FRAM Associated Press
# ..                                      ...
# 95                            Morgan Winsor
# 96                            Ben Gittleson
# 97                                 ABC News
# 98  Emily Shapiro, Jon Haworth, Karma Allen
# 99                             Libby Cathey
#
#                                                 title  \
# 0   Fauci: 'In a perfect world' Americans would st...
# 1   Coronavirus live updates: Establishments acros...
# 2   Coronavirus government response updates: Mnuch...
# 3               The month coronavirus changed America
# 4   Dems, GOP forge virus outbreak into '20 campai...
# ..                                                ...
# 95  Coronavirus live updates: Japan to begin quara...
# 96  Defense Production Act could help amid coronav...
# 97  WATCH: Timelapse of an empty Rome as shutdown ...
# 98  Coronavirus live updates: US death toll surpas...
# 99  Government coronavirus response: Trump declare...
#
#                                           description  \
# 0   Americans should avoid shaking hands -- “ever”...
# 1   There are at least 3,244 confirmed cases of no...
# 2   The Senate cleared a massive coronavirus relie...
# 3   At the beginning of of the month, the nation’s...
# 4   Coronavirus is already coloring the 2020 campaign
# ..                                                ...
# 95  A growing pandemic of the novel coronavirus ha...
# 96  President Donald Trump has resisted employing ...
# 97  Timelapse footage shows the almost deserted st...
# 98  Major cities are shutting down restaurants, ba...
# 99  President Trump declares a national emergency ...
#
#                                                   url  \
# 0   https://abcnews.go.com/Politics/fauci-perfect-...
# 1   https://abcnews.go.com/US/coronavirus-live-upd...
# 2   https://abcnews.go.com/Politics/coronavirus-go...
# 3   https://abcnews.go.com/Health/month-coronaviru...
# 4   https://abcnews.go.com/Politics/wireStory/dems...
# ..                                                ...
# 95  https://abcnews.go.com/Health/coronavirus-live...
# 96  https://abcnews.go.com/Politics/defense-produc...
# 97  https://abcnews.go.com/International/video/tim...
# 98  https://abcnews.go.com/US/coronavirus-live-upd...
# 99  https://abcnews.go.com/Politics/government-cor...
#
#                                            urlToImage           publishedAt  \
# 0   https://s.abcnews.com/images/Politics/fauci-rt...  2020-04-09T18:15:02Z
# 1   https://s.abcnews.com/images/US/new-york-dont-...  2020-03-16T08:34:31Z
# 2   https://s.abcnews.com/images/Politics/white-ho...  2020-03-26T16:22:11Z
# 3   https://s.abcnews.com/images/International/nyc...  2020-04-09T11:51:16Z
# 4   https://s.abcnews.com/images/Politics/WireAP_a...  2020-03-14T10:46:16Z
# ..                                                ...                   ...
# 95  https://s.abcnews.com/images/International/che...  2020-03-23T07:48:53Z
# 96  https://s.abcnews.com/images/Politics/supplies...  2020-03-25T21:52:18Z
# 97  https://s.abcnews.com/images/International/200...  2020-03-24T04:14:20Z
# 98  https://s.abcnews.com/images/International/cor...  2020-03-17T22:54:12Z
# 99  https://s.abcnews.com/images/Politics/trump-3-...  2020-03-13T21:04:49Z
#
#                                               content
# 0   Should the coronavirus pandemic mark the end o...
# 1   There are at least 3,244 confirmed cases of no...
# 2   The federal government has been rolling out it...
# 3   COVID-19's breakneck progression in the United...
# 4   WASHINGTON -- \r\nCoronavirus is already color...
# ..                                                ...
# 95  A growing pandemic of the novel coronavirus ha...
# 96  President Donald Trump's continued resistance ...
# 97  <li>Now Playing: Rome's Town Hall lights up in...
# 98  States are shutting down restaurants, bars, gy...
# 99  President Donald Trump announced Friday he's d...
#
# [100 rows x 8 columns]

# %%
abc_list=all_articles['articles']
for abc_articles in all_articles['articles']:
    print(Article(url=abc_articles['url']))
# Out:
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a25a1a8d0>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>
# <newspaper.article.Article object at 0x1a2534bc90>

# %%
type(abc_list)
# Out:
# list

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7b251b37acd0> in <module>
#       1 for artobj in abc_artobj:
# ----> 2     artobj.download()
#       3     artobj.keywords()
#
# AttributeError: 'dict' object has no attribute 'download'

# %%
# Out:
#                                       source  \
# 0   {'id': 'usa-today', 'name': 'USA Today'}
# 1   {'id': 'usa-today', 'name': 'USA Today'}
# 2   {'id': 'usa-today', 'name': 'USA Today'}
# 3   {'id': 'usa-today', 'name': 'USA Today'}
# 4   {'id': 'usa-today', 'name': 'USA Today'}
# 5   {'id': 'usa-today', 'name': 'USA Today'}
# 6   {'id': 'usa-today', 'name': 'USA Today'}
# 7   {'id': 'usa-today', 'name': 'USA Today'}
# 8   {'id': 'usa-today', 'name': 'USA Today'}
# 9   {'id': 'usa-today', 'name': 'USA Today'}
# 10  {'id': 'usa-today', 'name': 'USA Today'}
# 11  {'id': 'usa-today', 'name': 'USA Today'}
# 12  {'id': 'usa-today', 'name': 'USA Today'}
# 13  {'id': 'usa-today', 'name': 'USA Today'}
# 14  {'id': 'usa-today', 'name': 'USA Today'}
# 15  {'id': 'usa-today', 'name': 'USA Today'}
# 16  {'id': 'usa-today', 'name': 'USA Today'}
# 17  {'id': 'usa-today', 'name': 'USA Today'}
# 18  {'id': 'usa-today', 'name': 'USA Today'}
# 19  {'id': 'usa-today', 'name': 'USA Today'}
# 20  {'id': 'usa-today', 'name': 'USA Today'}
# 21  {'id': 'usa-today', 'name': 'USA Today'}
# 22  {'id': 'usa-today', 'name': 'USA Today'}
# 23  {'id': 'usa-today', 'name': 'USA Today'}
# 24  {'id': 'usa-today', 'name': 'USA Today'}
# 25  {'id': 'usa-today', 'name': 'USA Today'}
# 26  {'id': 'usa-today', 'name': 'USA Today'}
# 27  {'id': 'usa-today', 'name': 'USA Today'}
# 28  {'id': 'usa-today', 'name': 'USA Today'}
# 29  {'id': 'usa-today', 'name': 'USA Today'}
# 30  {'id': 'usa-today', 'name': 'USA Today'}
# 31  {'id': 'usa-today', 'name': 'USA Today'}
# 32  {'id': 'usa-today', 'name': 'USA Today'}
# 33  {'id': 'usa-today', 'name': 'USA Today'}
# 34  {'id': 'usa-today', 'name': 'USA Today'}
# 35  {'id': 'usa-today', 'name': 'USA Today'}
# 36  {'id': 'usa-today', 'name': 'USA Today'}
# 37  {'id': 'usa-today', 'name': 'USA Today'}
# 38  {'id': 'usa-today', 'name': 'USA Today'}
# 39  {'id': 'usa-today', 'name': 'USA Today'}
# 40  {'id': 'usa-today', 'name': 'USA Today'}
# 41  {'id': 'usa-today', 'name': 'USA Today'}
# 42  {'id': 'usa-today', 'name': 'USA Today'}
# 43  {'id': 'usa-today', 'name': 'USA Today'}
# 44  {'id': 'usa-today', 'name': 'USA Today'}
# 45  {'id': 'usa-today', 'name': 'USA Today'}
# 46  {'id': 'usa-today', 'name': 'USA Today'}
# 47  {'id': 'usa-today', 'name': 'USA Today'}
# 48  {'id': 'usa-today', 'name': 'USA Today'}
# 49  {'id': 'usa-today', 'name': 'USA Today'}
# 50  {'id': 'usa-today', 'name': 'USA Today'}
# 51  {'id': 'usa-today', 'name': 'USA Today'}
#
#                                                author  \
# 0              USA TODAY, Cydney Henderson, USA TODAY
# 1      NorthJersey.com, Chris Jordan, NorthJersey.com
# 2              USA TODAY, Cydney Henderson, USA TODAY
# 3              USA TODAY, Cydney Henderson, USA TODAY
# 4                     USA TODAY, Rasha Ali, USA TODAY
# 5                  USA TODAY, Frank Urbina, USA TODAY
# 6              USA TODAY, Cydney Henderson, USA TODAY
# 7   USA TODAY, Donovan Slack and Dinah Voyles Pulv...
# 8   Cincinnati Enquirer, James Weber, Cincinnati E...
# 9                                      Ryan W. Miller
# 10                  USA TODAY, Grace Hauck, USA TODAY
# 11         USA TODAY, USA TODAY Life staff, USA TODAY
# 12               USA TODAY, Ryan W. Miller, USA TODAY
# 13                                          Mike Bohn
# 14  Austin American-Statesman, Mark D. Wilson, Aus...
# 15  USA TODAY, N'dea Yancey-Bragg and Dalvin Brown...
# 16                                   MMA Junkie Staff
# 17                                    AP Domestic, AP
# 18  Salisbury Daily Times, Taylor Goebel, Salisbur...
# 19                                          Mike Bohn
# 20                 USA TODAY, Morgan Hines, USA TODAY
# 25  The CDC and a new study look at how long the c...
# 26  Paddy Pimblett is keener than most to keep the...
# 27  Shane Burgos is not going anywhere.\r\nThe ris...
# 28  From the CDC: How does COVID-19 spread?\r\nMil...
# 29  Spring breakers continue to party on beaches d...
# 30  Dana White sees UFC activity returning to norm...
# 31  Edmen Shahbazyan will have to wait a little lo...
# 32  Alabama\r\nMedical personnel screen a patient ...
# 33  Florida spring breakers and tourists still sta...
# 34  As flu season comes to an end and allergy seas...
# 35  SportsPulse: Sports plays a vital role in our ...
# 36  Last SlideNext Slide\r\nMEMPHIS -- Kevin Glona...
# 37  INDIANAPOLIS -- It is "reckless" to move forwa...
# 38  It’s not a great sign that the sports world ha...
# 39  Why do people act selfishly amid coronavirus a...
# 40  Comedians, actors, and musicians use their ext...
# 41  MEMPHIS, Tenn.  Meet the coronavirus. \r\nUnde...
# 42  SportsPulse: Founder, CEO and President of Uni...
# 43  HBO's free content, Drake's new song, the ACM'...
# 44  The coronavirus (COVID-19) is impacting the gl...
# 45  The world is scrambling to keep the spread of ...
# 46  USA TODAY TV Critic Kelly Lawler breaks down h...
# 47  It's hard keeping your kids entertained during...
# 48  Social distancing matters. Here is how to do i...
# 49  There is a lot of misinformation out there abo...
# 50  We answer the often searched question: "What a...
# 51  In this era of complicated diplomacy, what mor...

# %%
# Out:
# ['abc-news', 'al-jazeera-english', 'ars-technica', 'associated-press', 'axios', 'bleacher-report', 'bloomberg', 'breitbart-news', 'business-insider', 'buzzfeed', 'cbs-news', 'cnbc', 'cnn', 'cnn-es', 'crypto-coins-news', 'engadget', 'entertainment-weekly', 'espn', 'espn-cric-info', 'fortune', 'fox-news', 'fox-sports', 'google-news', 'hacker-news', 'ign', 'mashable', 'medical-news-today', 'msnbc', 'mtv-news', 'national-geographic', 'national-review', 'nbc-news', 'new-scientist', 'newsweek', 'new-york-magazine', 'next-big-future', 'nfl-news', 'nhl-news', 'politico', 'polygon', 'recode', 'reddit-r-all', 'reuters', 'techcrunch', 'techradar', 'the-american-conservative', 'the-hill', 'the-huffington-post', 'the-next-web', 'the-verge', 'the-wall-street-journal', 'the-washington-post', 'the-washington-times', 'time', 'usa-today', 'vice-news', 'wired']

# %%
# Out:
#   File "<ipython-input-8-cf18d4540656>", line 1
#     abc_covid=
#               ^
# SyntaxError: invalid syntax

# %%
##This is python code that I found for using RAPIDAPI. Still need help to find API for it. 

import requests  # install from: http://docs.python-requests.org/en/master/

# Replace the following string value with your valid X-RapidAPI-Key.
Your_X_RapidAPI_Key = "XXXXXXXXXXXXXXXXXXX";

# The query parameters: (update according to your search query)
q = "Taylor%20Swift"  # the search query
pageNumber = 1  # the number of requested page
pageSize = 10  # the size of a page
autoCorrect = True  # autoCorrectspelling
safeSearch = False  # filter results for adult content

response = requests.get(
    "https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/Search/NewsSearchAPI?q={}&pageNumber={}&pageSize={}&autocorrect={}&safeSearch={}".format(
        q, pageNumber, pageSize, autoCorrect, safeSearch),
    headers={
        "X-RapidAPI-Key": Your_X_RapidAPI_Key
    }
).json()

# Get the numer of items returned
totalCount = response["totalCount"];

# Get the list of most frequent searches related to the input search query
relatedSearch = response["relatedSearch"]

# Go over each resulting item
for webPage in response["value"]:
    # Get the web page metadata
    url = webPage["url"]
    title = webPage["title"]
    description = webPage["description"]
    keywords = webPage["keywords"]
    provider = webPage["provider"]["name"]
    datePublished = webPage["datePublished"]

    # Get the web page image (if exists)
    imageUrl = webPage["image"]["url"]
    imageHeight = webPage["image"]["height"]
    imageWidth = webPage["image"]["width"]

    thumbnail = webPage["image"]["thumbnail"]
    thumbnailHeight = webPage["image"]["thumbna`enter code here`ilHeight"]

# An example: Output the webpage url, title and published date:
print("Url: %s. Title: %s. Published Date:%s." % (url, title, datePublished))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-cd4bd36f8cbb> in <module>
#      22
#      23 # Get the numer of items returned
# ---> 24 totalCount = response["totalCount"];
#      25
#      26 # Get the list of most frequent searches related to the input search query
#
# KeyError: 'totalCount'

# %%
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize.regexp import WhitespaceTokenizer
import numpy as np
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /Users/hsaul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/hsaul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
bbc_paper = newspaper.build('http://bbc.com', memoize_articles=False)
for article in bbc_paper.articles:
     print(article.url)
# Out:
# http://bbc.com/portuguese/media/video
# http://www.bbc.com/portuguese/media/video
# https://www.bbc.com/portuguese/media/photogalleries
# http://bbc.com/tamil/media/video
# http://bbc.com/tamil/resources/idt-ce219e77-9003-42b8-b276-1214e232fdc0
# http://www.bbc.com/tamil/media/video
# https://www.bbc.co.uk/news/localnews
# http://bbc.com/news/live/world-52225173
# http://bbc.com/news/world
# https://www.bbc.com/news/business-52236936
# http://bbc.com/news/business
# https://www.bbc.com/news/world-asia-52230833
# http://bbc.com/news/world/asia
# https://www.bbc.com/culture/story/20200409-rainbows-as-signs-of-thank-you-hope-and-solidarity
# https://www.bbc.com/news/uk-england-dorset-52228493
# http://bbc.com/news/england/dorset
# http://bbc.com/news/uk-politics-52238276
# http://bbc.com/news/politics
# http://bbc.com/news/world-us-canada-52230979
# http://bbc.com/news/world/us_and_canada
# http://bbc.com/news/world-us-canada-52238591
# https://www.bbc.com/news/explainers
# https://www.bbc.com/worklife/article/20200408-coronavirus-how-lockdown-helps-those-who-fear-the-phone
# https://www.bbc.com/travel/story/20200407-turkeys-unique-hand-sanitiser
# https://www.bbc.com/future/article/20200408-an-astronauts-guide-to-surviving-isolation
# http://bbc.com/reel/video/p088mmx4/the-remote-italian-village-sealed-off-from-the-world
# http://bbc.com/reel/video/p086tl5n/what-s-the-point-of-believing-we-have-free-will-
# http://bbc.com/reel/video/p088t8gm/the-world-s-fastest-sinking-city
# https://www.bbc.com/travel/story/20200408-how-boredom-can-inspire-adventure
# https://www.bbc.com/future/article/20200408-the-middle-eastern-corals-that-could-survive-climate-change
# https://www.bbc.com/culture/story/20200407-the-surprising-story-of-polands-extraordinary-churches
# https://www.bbc.com/future/article/20200407-urban-mining-how-your-home-may-be-a-gold-mine
# https://www.bbc.com/swahili/taasisi/2011/10/000001_terms_of_use
# https://www.bbc.com/swahili/taasisi/2011/10/000001_aboutus
# https://www.bbc.com/swahili/taasisi/2011/10/000001_privacy
# https://www.bbc.com/swahili/taasisi/2011/10/000001_contactus
# http://bbc.com/mundo/media/video
# http://www.bbc.com/mundo/media/photogalleries
# http://www.bbc.com/indonesia/media/video
# https://www.bbc.com/indonesia/institutional/2011/02/000001_links
# http://bbc.com/arabic/media
# http://www.bbc.com/arabic/media/video
# http://bbc.com/arabic/institutional/2011/01/000000_frequencies_radio
# http://www.bbc.com/arabic/institutional/2013/04/130415_bbcarabic_partners.shtml
# https://www.bbc.co.uk/news/extra/8DKxx1xOoL/sexplainer
# http://www.bbc.com/arabic/media/photogalleries

# %%
bbc_articles= pd.DataFrame(bbc_paper.articles)
bbc_articles
# Out:
#                                                      0
# 0    <newspaper.article.Article object at 0x1a25b62...
# 1    <newspaper.article.Article object at 0x1a25a90...
# 2    <newspaper.article.Article object at 0x11e302090>
# 3    <newspaper.article.Article object at 0x1a25ee7...
# 4    <newspaper.article.Article object at 0x1a25ee7...
# ..                                                 ...
# 370  <newspaper.article.Article object at 0x1a25bc4...
# 371  <newspaper.article.Article object at 0x1a25e26...
# 372  <newspaper.article.Article object at 0x1a25e26...
# 373  <newspaper.article.Article object at 0x1a25e26...
# 374  <newspaper.article.Article object at 0x1a25e19...
#
# [375 rows x 1 columns]

# %%
type(bbc_paper)
# Out:
# newspaper.source.Source

# %%
for category in bbc_paper.category_urls():
  print(category)
# Out:
# http://bbc.com/portuguese
# http://bbc.com/tamil
# http://bbc.com
# http://bbc.com/russian
# http://bbc.com/reel
# http://bbc.com/hindi
# http://bbc.com/gahuza
# http://bbc.com/urdu
# http://bbc.com/persian
# http://bbc.com/pashto
# http://bbc.com/somali
# http://bbc.com/nepali
# http://bbc.com/afrique
# http://www.bbc.co.uk
# http://bbc.com/sinhala
# http://bbc.com/kyrgyz
# http://bbc.com/vietnamese
# http://bbc.com/uzbek
# http://bbc.com/burmese
# http://bbc.com/marathi
# http://bbc.com/japanese
# http://www.bbc.com
# https://www.bbc.com
# http://bbc.com/bengali
# http://bbc.com/turkce
# http://bbc.com/hausa
# http://bbc.com/ukrainian
# http://bbc.com/news
# https://www.bbc.co.uk
# http://bbc.com/azeri
# http://bbc.com/swahili
# http://bbc.com/mundo
# http://bbc.com/indonesia
# http://bbc.com/arabic
# http://bbc.com/sport

# %%
f2=bbc_paper.articles[18]
f2

# %%
f2=bbc_paper.articles[18]
f2.download()
f2.parse()
print(f2.text)
# Out:
# Image copyright Getty Images
#
# Bernie Sanders formally suspended his presidential campaign on Wednesday, acknowledging that he had no realistic path to winning the Democratic nomination.
#
# In reality, however, the campaign's death blow came weeks earlier, in Michigan and Missouri, before the Democratic primary season entered suspended animation for weeks, with the coronavirus pandemic shuttering the campaigns and forcing states to postpone their primaries.
#
# It was at that point that it had become painfully clear for all but the most devoted Sanders faithful that there would be no rebound for the campaign; no revival of flagging momentum. Those defeats broke the back of the campaign, with the coronavirus outbreak only temporarily delaying the final reckoning.
# Another big what-if that will torment the Sanders faithful in the days ahead is whether, while the centrists united, divisions within their own ranks cost them victory.
#
# Elizabeth Warren, the progressive senator from Massachusetts, was probably closest to Sanders ideologically among the Democratic candidates. She dropped out of the race shortly after a string of disappointing finishes on Super Tuesday, but she pointedly declined to endorse Sanders. Instead, she noted that they had much in common from a policy perspective, but some of his supporters were abusive.
#
# Warren and Sanders had exchanged heated words after a contentious February debate in Iowa, and in the days that followed Warren was savaged on social media by Sanders loyalists, who called her a snake and a traitor. While the Sanders camp reportedly made overtures to Warren's staffers around Super Tuesday, they viewed those efforts as too little, too late.
#
# Meanwhile, the Sanders' side sees Warren's cold shoulder as a stinging and costly betrayal.
#
# "They had a fork in the road, and they chose to be silent and do nothing," Solomon said. "By doing nothing, it was an explicit boost to Biden, and that will always be on her record. We're never going to forget that."
#
# Black swans
#
# Some of the pitfalls and obstacles facing the Sanders campaign - such as the struggle to win the support of black voters, critical media coverage, the reluctance of the Democratic establishment and centrists to make peace with the senator, and the negative connotations of his self-proclaimed "Democratic socialist" identity among parts of the electorate - were predictable.
#
# Then there were the unexpected "black swan" events that posed particular challenges to Sanders.
#
# His heart attack in October threatened to derail the entire campaign. Donald Trump's impeachment trial in January kept Sanders tied to Washington, DC for two weeks, while other candidates - particularly Buttigieg - were able to turn repeated trips through Iowa and New Hampshire into growing support.
#
# Image copyright Getty Images
#
# Finally, the coronavirus outbreak put a Sanders campaign that was already on its heels after a string of defeats into indefinite deep-freeze.
#
# While the chances of a comeback were remote given Biden's lead in national convention delegates after his March wins, state after state delayed their primary contests into June. There was no chance of a surprise victory; no hope of a change in momentum.
#
# And when Wisconsin, a state Sanders won comfortably in 2016, decided to move forward with its vote this week, social distancing and shelter-in-place orders ensured that Sanders was unable to hold his trademark raucous rallies or deploy his millions of door-knocking volunteers even if he wanted to.
#
# The reality was unavoidable, and on Wednesday Sanders acknowledged it.
#
# Media playback is unsupported on your device Media caption Sanders addresses supporters: 'I wish I had better news'
#
# "As I see the crisis gripping the nation, I cannot in good conscience continue" he said in video broadcast from his home in Vermont. "I wish I could give you better news, but I think you know the truth and that is we are some 300 delegates behind Vice-President Joe Biden and the path toward victory is virtually impossible."
#
# Sanders added that he would remain on the ballot in the remainder of the primaries and hoped to amass more delegates to give him the ability to influence the party's manifesto and rules at the national convention, which has been delayed to August. The active campaign, however, was done.
#
# The road ahead
#
# In his Wednesday concession speech Sanders also struck a hopeful note, saying that although his campaign was coming to an end, the movement he created was not.
#
# "While the path may be slower now, we will change this nation, and with like-minded friends around the globe, change the entire world," he said.
#
# In just five years Sanders created a movement essentially out of thin air. When he kicked off his first presidential bid in April 2015, it was with a sparsely attended press conference on the grounds of the U.S. Capitol. There was little indication at the time of the grass-roots and fundraising juggernaut that would follow.
#
# The politician who had spent decades as back-bencher in Congress transformed himself into the leader of a popular, grass-roots force that electrified supporters and sent traditional party power-brokers scrambling. He became, arguably, the most influential force on the party in recent memory - at the very least on a short list with Barack Obama, Nancy Pelosi and Bill Clinton. And his power came not from the office he held, but from the people he spoke to - and for.
#
# Now the 78-year-old senator is approaching the twilight of his political career, and it seems unlikely he will again try to head the Democratic national ticket. The question, then, becomes who will lead of the movement going forward.
#
# Warren is an obvious choice - if the acrimony of the recent campaign eventually settles. New York Congresswoman Ocasio-Cortez is the rising star in the progressive ranks. Her endorsement of the senator shortly after his heart attack is credited with reviving what was at the time a flagging campaign.
#
# Image copyright Getty Images Image caption A passing of the torch?
#
# Other Sanders advocates - Congressman Ro Khanna of California and Congresswoman Pramila Jayapal of Washington are also seen as young, charismatic figures.
#
# "Bernie is very beloved, and he's going to continue in the Senate and as a public person for many years to come," Solomon said. "But the leadership is going to diversify."
#
# He added that outside of elected officials, the ranks of progressive activists continues to grow, and the movement is creating its own media outlets to counter with what he says is the unfair coverage of the mainstream press.
#
# The bottom line, he concludes, is that Sanders has opened a door for the next generation of liberal grass-roots candidates - ones who might finally win a White House prize that seemed, for at least a few weeks this year, tantalisingly within his reach.
#
# "The Democratic Party establishment still retains a lot of power," Solomon said. "Yet in contrast with four years ago, there's now an understanding from the hierarchy that they can't just tell progressives to go jump in a lake. If they do that, people like Trump win."

# %%
print(f2.title)

# %%
f2.nlp()
f2.keywords

# %%
import cv2def

# %%
create_mask():
    mask = np.array(Image.open("coronavirus.png"))
    im_gray = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    _, mask = cv2.threshold(im_gray, thresh=20, maxval=255, type=cv2.THRESH_BINARY)
    mask = 255 - mask
    return maskmask = create_mask()def create_wc_by(source):
    data = fulldf[fulldf['source']==source]
    text = " ".join([x for x in data.content.values if x is not None])
    stopwords = set(STOPWORDS)
    stopwords.add('chars')
    stopwords.add('coronavirus')
    stopwords.add('corona')
    stopwords.add('chars')
    wc = WordCloud(background_color="white", max_words=1000, mask=mask, stopwords=stopwords,
               max_font_size=90, random_state=42, contour_width=3, contour_color='steelblue')
    wc.generate(text)
    plt.figure(figsize=[30,30])
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    return pltst.pyplot(create_wc_by(source),use_container_width=True)

# %%
print (join(list(chain.from_iterable(filtered_sentence))))

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
vect.set_params(tokenizer=tokenizer.tokenize(p2.text))

# remove English stop words
vect.set_params(stop_words='english')

# include 1-grams and 2-grams
vect.set_params(ngram_range=(1, 2))

# ignore terms that appear in more than 50% of the documents
vect.set_params(max_df=0.5)

# only keep terms that appear in at least 2 documents
vect.set_params(min_df=2)

# %%
vect

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokenizer.tokenize(p2.text)

# %%
from nltk import word_tokenize
tokens = word_tokenize(p2.text)
print(tokens)

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
print(stop_words)

# %%
filtered_sentence = []
for word in tokens:
    if word not in stop_words:
        filtered_sentence.append(word)
print(tokens)
print("=================================================================================")
print(filtered_sentence)

# %%
list(nltk.FreqDist(filtered_sentence).values())

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(df['Review Text'], 20)
for word, freq in common_words:
    print(word, freq)
df1 = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
df1.groupby('ReviewText').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words in review before removing stop words')
view raw
