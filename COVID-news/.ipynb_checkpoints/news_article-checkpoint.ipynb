# %%
import pprint 
import requests 
import eventregistry
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime

# %%
secret = "f513e29c94b844758f79311e9e081927"
   
# Define the endpoint 
url = 'https://newsapi.org/v2/everything?'
   
# Specify the query and 
# number of returns 
parameters = { 
    'q': 'coronavirus', # query phrase 
    'pageSize': 100,  # maximum is 100 
    'apiKey': secret # your own API key 
} 
   
# Make the request 
response = requests.get(url,  
                        params = parameters) 
   
# Convert the response to  
# JSON format and pretty print it 
response_json = response.json() 
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Nicole Dieker',
#                'content': 'There are a lot of people trying to make money off '
#                           'coronavirus anxiety right now, whether by charging '
#                           '$79 for a bottle of Purell, selling counterfeit '
#                           'face masks on Etsy, or claiming that you can cure '
#                           'COVID-19 with essential oils.\r\n'
#                           'There are also a handful of … [+1825 chars]',
#                'description': 'There are a lot of people trying to make money '
#                               'off coronavirus anxiety right now, whether by '
#                               'charging $79 for a bottle of Purell, selling '
#                               'counterfeit face masks on Etsy, or claiming '
#                               'that you can cure COVID-19 with essential oils. '
#                               'Read more...',
# ...

# %%
response_json[0]['url']['title']
print(url, title)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-0e6c4667da8f> in <module>
# ----> 1 response_json[0]['url']['title']
#       2 print(url, title)
#
# KeyError: 0

# %%
# Set the limit for number of articles to download
LIMIT = 10

data = {}
data['newspapers'] = {}

# %%
News_Papers.JSON={
  "cnn": {
    "link": "http://edition.cnn.com/"
  },
  "bbc": {
    "rss": "http://feeds.bbci.co.uk/news/rss.xml",
    "link": "http://www.bbc.com/"
  },
  "theguardian": {
    "rss": "https://www.theguardian.com/uk/rss",
    "link": "https://www.theguardian.com/international"
  },
  "breitbart": {
    "link": "http://www.breitbart.com/"
  },
  "infowars": {
    "link": "https://www.infowars.com/"
  },
  "foxnews": {
    "link": "http://www.foxnews.com/"
  },
  "nbcnews": {
    "link": "http://www.nbcnews.com/"
  },
  "washingtonpost": {
    "rss": "http://feeds.washingtonpost.com/rss/world",
    "link": "https://www.washingtonpost.com/"
  },
  "nytimes": {
    "link": "http://www.nytimes.com/"
  }
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9bec379bb2f3> in <module>
#      28   },
#      29   "nytimes": {
# ---> 30     "link": "http://www.nytimes.com/"
#      31   }
#      32 }
#
# NameError: name 'News_Papers' is not defined

# %%
# Loads the JSON files with news sites
with open('News_Papers.json') as data_file:
    companies = json.load(data_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-dd7b8d3c4c29> in <module>
#       1 # Loads the JSON files with news sites
# ----> 2 with open('News_Papers.json') as data_file:
#       3     companies = json.load(data_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'News_Papers.json'
