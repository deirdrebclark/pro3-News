# %%
pip install alpha-vantage
# pip install pandas
# pip install matplotlib
# Out:
#   File "<ipython-input-10-f0081397604e>", line 1
#     pip install alphavantage
#               ^
# SyntaxError: invalid syntax

# %%
import requests
import json
from pprint import pprint
from config import AV_API_Key

# %%
url = 'https://www.alphavantage.co/query?'
seriesWeekly = 'TIME_SERIES_WEEKLY'
tickerSP = 'SP'
query_url = f"{url}function={seriesWeekly}&symbol={tickerSP}&apikey={AV_API_Key}"

# %%
output = requests.get(query_url).json()
pprint (output)
# Out:
#                   '5. volume': '470988'},
#                         '2019-01-18': {'1. open': '33.2600',
#                                        '2. high': '34.4100',
#                                        '3. low': '33.0000',
#                                        '4. close': '34.3800',
#                                        '5. volume': '365848'},
#                         '2019-01-25': {'1. open': '34.1500',
#                                        '2. high': '34.6100',
#                                        '3. low': '34.0000',
#                                        '4. close': '34.0700',
#                                        '5. volume': '269112'},
#                         '2019-02-01': {'1. open': '33.8100',
#                                        '2. high': '34.0199',
#                                        '3. low': '32.6700',
#                                        '4. close': '33.1600',
#                                        '5. volume': '558315'},
#                         '2019-02-08': {'1. open': '33.1700',
#                                        '2. high': '34.5200',
#                                        '3. low': '33.0600',
#                                        '4. close': '34.4900',
#                                        '5. volume': '363387'},
#                         '2019-02-15': {'1. open': '34.7100',
#                                        '2. high': '36.9200',
#                                        '3. low': '34.1390',
#                                        '4. close': '36.7200',
#                                        '5. volume': '319400'},
#                         '2019-02-22': {'1. open': '36.7200',
#                                        '2. high': '38.6400',
#                                        '3. low': '35.5970',
#                                        '4. close': '36.3400',
#                                        '5. volume': '521564'},
#                         '2019-03-01': {'1. open': '36.5400',
#                                        '2. high': '37.3700',
#                                        '3. low': '34.1500',
#                                        '4. close': '34.5100',
#                                        '5. volume': '577881'},
#                         '2019-03-08': {'1. open': '34.6200',
#                                        '2. high': '34.9600',
#                                        '3. low': '33.1550',
#                                        '4. close': '33.2900',
#                                        '5. volume': '412795'},
#                         '2019-03-15': {'1. open': '33.3800',
#                                        '2. high': '34.1800',
#                                        '3. low': '33.1100',
#                                        '4. close': '33.7900',
#                                        '5. volume': '532750'},
#                         '2019-03-22': {'1. open': '33.8400',
#                                        '2. high': '34.9412',
#                                        '3. low': '32.4300',
#                                        '4. close': '32.7600',
#                                        '5. volume': '542924'},
#                         '2019-03-29': {'1. open': '32.7000',
#                                        '2. high': '34.3500',
#                                        '3. low': '32.5100',
#                                        '4. close': '34.1200',
#                                        '5. volume': '427145'},
#                         '2019-04-05': {'1. open': '34.1300',
#                                        '2. high': '34.4900',
#                                        '3. low': '31.7900',
#                                        '4. close': '33.4500',
#                                        '5. volume': '575317'},
#                         '2019-04-12': {'1. open': '33.4400',
#                                        '2. high': '33.9600',
#                                        '3. low': '33.0000',
#                                        '4. close': '33.9300',
#                                        '5. volume': '450128'},
#                         '2019-04-18': {'1. open': '33.9800',
#                                        '2. high': '34.7700',
#                                        '3. low': '33.8908',
#                                        '4. close': '34.3700',
#                                        '5. volume': '301906'},
#                         '2019-04-26': {'1. open': '34.1800',
#                                        '2. high': '34.9900',
#                                        '3. low': '33.9450',
#                                        '4. close': '34.6400',
#                                        '5. volume': '240893'},
#                         '2019-05-03': {'1. open': '34.6800',
#                                        '2. high': '35.0000',
#                                        '3. low': '33.6850',
#                                        '4. close': '33.8500',
#                                        '5. volume': '442896'},
#                         '2019-05-10': {'1. open': '33.4300',
#                                        '2. high': '33.9750',
#                                        '3. low': '32.3100',
#                                        '4. close': '33.0000',
#                                        '5. volume': '510709'},
#                         '2019-05-17': {'1. open': '32.4800',
#                                        '2. high': '33.4500',
#                                        '3. low': '31.8686',
#                                        '4. close': '32.7400',
#                                        '5. volume': '424996'},
#                         '2019-05-24': {'1. open': '32.6100',
#                                        '2. high': '33.0700',
#                                        '3. low': '31.4700',
#                                        '4. close': '31.5300',
#                                        '5. volume': '511855'},
#                         '2019-05-31': {'1. open': '31.5000',
#                                        '2. high': '31.7500',
#                                        '3. low': '30.6550',
#                                        '4. close': '31.0300',
#                                        '5. volume': '619213'},
#                         '2019-06-07': {'1. open': '31.1000',
#                                        '2. high': '33.0500',
#                                        '3. low': '30.8800',
#                                        '4. close': '32.4400',
#                                        '5. volume': '653439'},
#                         '2019-06-14': {'1. open': '32.6200',
#                                        '2. high': '33.5000',
#                                        '3. low': '32.1400',
#                                        '4. close': '32.2300',
#                                        '5. volume': '367539'},
#                         '2019-06-21': {'1. open': '32.2800',
#                                        '2. high': '32.8900',
#                                        '3. low': '32.0000',
#                                        '4. close': '32.0100',
#                                        '5. volume': '536948'},
#                         '2019-06-28': {'1. open': '32.0200',
#                                        '2. high': '32.4400',
#                                        '3. low': '31.2300',
#                                        '4. close': '31.9300',
#                                        '5. volume': '900264'},
#                         '2019-07-05': {'1. open': '32.0600',
#                                        '2. high': '33.8600',
#                                        '3. low': '32.0500',
#                                        '4. close': '33.3800',
#                                        '5. volume': '491980'},
#                         '2019-07-12': {'1. open': '33.3600',
#                                        '2. high': '33.4550',
#                                        '3. low': '32.0050',
#                                        '4. close': '32.8400',
#                                        '5. volume': '301929'},
#                         '2019-07-19': {'1. open': '32.8400',
#                                        '2. high': '34.5300',
#                                        '3. low': '32.5500',
#                                        '4. close': '33.8300',
#                                        '5. volume': '358993'},
#                         '2019-07-26': {'1. open': '33.7800',
#                                        '2. high': '35.4900',
#                                        '3. low': '33.0500',
#                                        '4. close': '35.2900',
#                                        '5. volume': '474053'},
#                         '2019-08-02': {'1. open': '35.1800',
#                                        '2. high': '38.0600',
#                                        '3. low': '33.8766',
#                                        '4. close': '35.0100',
#                                        '5. volume': '596560'},
#                         '2019-08-09': {'1. open': '34.6900',
#                                        '2. high': '35.3300',
#                                        '3. low': '33.1400',
#                                        '4. close': '35.0400',
#                                        '5. volume': '442278'},
#                         '2019-08-16': {'1. open': '34.7600',
#                                        '2. high': '35.3854',
#                                        '3. low': '33.7400',
#                                        '4. close': '34.9300',
#                                        '5. volume': '297653'},
#                         '2019-08-23': {'1. open': '35.2900',
#                                        '2. high': '35.3600',
#                                        '3. low': '33.6600',
#                                        '4. close': '33.7500',
#                                        '5. volume': '353898'},
#                         '2019-08-30': {'1. open': '33.9600',
#                                        '2. high': '34.8900',
#                                        '3. low': '33.6700',
#                                        '4. close': '34.5100',
#                                        '5. volume': '392319'},
#                         '2019-09-06': {'1. open': '34.2700',
#                                        '2. high': '35.8300',
#                                        '3. low': '33.9800',
#                                        '4. close': '34.7800',
#                                        '5. volume': '254601'},
#                         '2019-09-13': {'1. open': '35.0700',
#                                        '2. high': '37.6800',
#                                        '3. low': '34.6600',
#                                        '4. close': '37.1200',
#                                        '5. volume': '411964'},
#                         '2019-09-20': {'1. open': '37.1200',
#                                        '2. high': '37.7700',
#                                        '3. low': '36.3400',
#                                        '4. close': '37.4400',
#                                        '5. volume': '383500'},
#                         '2019-09-27': {'1. open': '37.3200',
#                                        '2. high': '37.9200',
#                                        '3. low': '36.2800',
#                                        '4. close': '37.4000',
#                                        '5. volume': '523150'},
#                         '2019-10-04': {'1. open': '37.3100',
#                                        '2. high': '37.8084',
#                                        '3. low': '36.7077',
#                                        '4. close': '37.3700',
#                                        '5. volume': '559139'},
#                         '2019-10-11': {'1. open': '37.3000',
#                                        '2. high': '38.5900',
#                                        '3. low': '36.9200',
#                                        '4. close': '37.7100',
#                                        '5. volume': '411391'},
#                         '2019-10-18': {'1. open': '37.5200',
#                                        '2. high': '38.8600',
#                                        '3. low': '37.0600',
#                                        '4. close': '38.4300',
#                                        '5. volume': '424734'},
#                         '2019-10-25': {'1. open': '38.8000',
#                                        '2. high': '39.6400',
#                                        '3. low': '38.2450',
#                                        '4. close': '38.8800',
#                                        '5. volume': '449001'},
#                         '2019-11-01': {'1. open': '38.9400',
#                                        '2. high': '45.4300',
#                                        '3. low': '38.9400',
#                                        '4. close': '45.3100',
#                                        '5. volume': '914462'},
#                         '2019-11-08': {'1. open': '45.9200',
#                                        '2. high': '47.3300',
#                                        '3. low': '45.3700',
#                                        '4. close': '45.7800',
#                                        '5. volume': '792457'},
#                         '2019-11-15': {'1. open': '45.7800',
#                                        '2. high': '46.1400',
#                                        '3. low': '43.7400',
#                                        '4. close': '43.9100',
#                                        '5. volume': '447450'},
#                         '2019-11-22': {'1. open': '43.8000',
#                                        '2. high': '45.0400',
#                                        '3. low': '43.1300',
#                                        '4. close': '43.2000',
#                                        '5. volume': '499990'},
#                         '2019-11-29': {'1. open': '43.3000',
#                                        '2. high': '45.1000',
#                                        '3. low': '43.3000',
#                                        '4. close': '43.8500',
#                                        '5. volume': '709428'},
#                         '2019-12-06': {'1. open': '43.8900',
#                                        '2. high': '45.1900',
#                                        '3. low': '43.2150',
#                                        '4. close': '44.7100',
#                                        '5. volume': '735583'},
#                         '2019-12-13': {'1. open': '44.8000',
#                                        '2. high': '45.0800',
#                                        '3. low': '43.2200',
#                                        '4. close': '43.5200',
#                                        '5. volume': '363859'},
#                         '2019-12-20': {'1. open': '43.7200',
#                                        '2. high': '44.2600',
#                                        '3. low': '42.1700',
#                                        '4. close': '43.6600',
#                                        '5. volume': '555538'},
#                         '2019-12-27': {'1. open': '43.7000',
#                                        '2. high': '43.7000',
#                                        '3. low': '42.2500',
#                                        '4. close': '42.7200',
#                                        '5. volume':'210791'},
#                         '2020-01-03': {'1. open': '42.7900',
#                                        '2. high': '43.0200',
#                                        '3. low': '41.8900',
#                                        '4. close': '42.4000',
#                                        '5. volume': '379504'},
#                         '2020-01-10': {'1. open': '42.1100',
#                                        '2. high': '42.8700',
#                                        '3. low': '41.7900',
#                                        '4. close': '41.9400',
#                                        '5. volume': '326171'},
#                         '2020-01-17': {'1. open': '41.8800',
#                                        '2. high': '42.3200',
#                                        '3. low': '41.0800',
#                                        '4. close': '41.1100',
#                                        '5. volume': '376661'},
#                         '2020-01-24': {'1. open': '40.9900',
#                                        '2. high': '41.9000',
#                                        '3. low': '40.5900',
#                                        '4. close': '40.8000',
#                                        '5. volume': '294073'},
#                         '2020-01-31': {'1. open': '40.0700',
#                                        '2. high': '42.0800',
#                                        '3. low': '40.0700',
#                                        '4. close': '41.8100',
#                                        '5. volume': '543816'},
#                         '2020-02-07': {'1. open': '41.9300',
#                                        '2. high': '43.8400',
#                                        '3. low': '41.9300',
#                                        '4. close': '43.4900',
#                                        '5. volume': '335280'},
#                         '2020-02-14': {'1. open': '43.3300',
#                                        '2. high': '44.2600',
#                                        '3. low': '42.9000',
#                                        '4. close': '43.6700',
#                                        '5. volume': '400874'},
#                         '2020-02-21': {'1. open': '43.7300',
#                                        '2. high': '46.6500',
#                                        '3. low': '38.0300',
#                                        '4. close': '38.2700',
#                                        '5. volume': '777842'},
#                         '2020-02-28': {'1. open': '37.3600',
#                                        '2. high': '38.7700',
#                                        '3. low': '34.9100',
#                                        '4. close': '36.5100',
#                                        '5. volume': '839773'},
#                         '2020-03-06': {'1. open': '36.4200',
#                                        '2. high': '39.1750',
#                                        '3. low': '36.4200',
#                                        '4. close': '37.8900',
#                                        '5. volume': '829723'},
#                         '2020-03-13': {'1. open': '37.0600',
#                                        '2. high': '37.4200',
#                                        '3. low': '27.2300',
#                                        '4. close': '30.4800',
#                                        '5. volume': '882194'},
#                         '2020-03-20': {'1. open': '27.6700',
#                                        '2. high': '27.9900',
#                                        '3. low': '14.4400',
#                                        '4. close': '18.6000',
#                                        '5. volume': '1230904'},
#                         '2020-03-27': {'1. open': '18.4300',
#                                        '2. high': '24.6095',
#                                        '3. low': '17.1300',
#                                        '4. close': '21.9200',
#                                        '5. volume': '1171351'},
#                         '2020-04-03': {'1. open': '22.1600',
#                                        '2. high': '22.6551',
#                                        '3. low': '16.8600',
#                                        '4. close': '17.4600',
#                                        '5. volume': '928255'},
#                         '2020-04-09': {'1. open': '18.2400',
#                                        '2. high': '22.6700',
#                                        '3. low': '17.5600',
#                                        '4. close': '22.5100',
#                                        '5. volume': '1532623'}}}
